# %% [markdown]
# <a href="https://colab.research.google.com/github/karthickb77/AENEXZ_TASKS-NO.1/blob/main/VOWEL%20AND%20CONSONANT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
character= input("Enter the charactern:")
if character in 'AEIOUaeiou':
  print("vowel")
else:
  print("consonant")
# Out:
# Enter the charactern:r
# consonant
