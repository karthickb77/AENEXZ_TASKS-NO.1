# %% [markdown]
# <a href="https://colab.research.google.com/github/karthickb77/AENEXZ_TASKS-NO.1/blob/main/LEAP_YEAAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter a year: 2000
# 2000 is a Leap Year
