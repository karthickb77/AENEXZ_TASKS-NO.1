# %% [markdown]
# <a href="https://colab.research.google.com/github/karthickb77/AENEXZ_TASKS-NO.1/blob/main/NATURAL_NUMBERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter the value of N: "))
sum = 0
i = 1
while i <= n:
  sum +=i
  i +=1
print("Sum of first", n, "natural numbers is:", sum)
