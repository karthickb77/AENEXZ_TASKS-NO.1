# %% [markdown]
# <a href="https://colab.research.google.com/github/karthickb77/AENEXZ_TASKS-NO.1/blob/main/DIVISIBLE%20BY%205%20AND%2011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("Enter a number: "))

if number % 5 == 0 and number % 11 == 0:
    print(number, "is divisible by both 5 and 11")
else:
    print(number, "is not divisible by both 5 and 11")
# Out:
# Enter a number: 55
# 55 is divisible by both 5 and 11
