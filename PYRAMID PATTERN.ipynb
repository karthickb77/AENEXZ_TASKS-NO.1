# %% [markdown]
# <a href="https://colab.research.google.com/github/karthickb77/AENEXZ_TASKS-NO.1/blob/main/PYRAMID%20PATTERN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r = 7
i = 1

while i <= r:
    spaces = r - i
    stars = 2 * i - 1

    print(" " * spaces + "*" * stars)
    i += 1
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************
