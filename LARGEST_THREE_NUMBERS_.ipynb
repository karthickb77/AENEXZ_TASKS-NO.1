# %% [markdown]
# <a href="https://colab.research.google.com/github/karthickb77/AENEXZ_TASKS-NO.1/blob/main/LARGEST_THREE_NUMBERS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def find_l3(a,b,c):
  if a>=b and b>=c:
    return a
  elif b>=a and b>=c:
    return b
  else:
    return c

n1,n2,n3 = 10,30,45
print(find_l3(n1,n2,n3))
# Out:
# 45
